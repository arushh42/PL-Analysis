# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
url_df = 'https://fbref.com/en/comps/9/stats/Premier-League-Stats#all_stats_standard'
df = pd.read_html(url_df)
df
# Out:
# [   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0
#                  Squad               # Pl                Age
#  0             Arsenal                 23               25.3  \
#  1         Aston Villa                 26               27.4
#  2         Bournemouth                 25               26.1
#  3           Brentford                 26               27.1
#  4            Brighton                 27               26.7
#  5             Burnley                 26               25.3
#  6             Chelsea                 28               25.0
#  7      Crystal Palace                 24               27.6
#  8             Everton                 25               27.4
#  9              Fulham                 24               29.3
#  10          Liverpool                 23               27.3
#  11         Luton Town                 23               27.2
#  12    Manchester City                 25               27.0
# ...

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
df = pd.read_html(url_df)[0]
df
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0
#                 Squad               # Pl                Age
# 0             Arsenal                 23               25.3  \
# 1         Aston Villa                 26               27.4
# 2         Bournemouth                 25               26.1
# 3           Brentford                 26               27.1
# 4            Brighton                 27               26.7
# 5             Burnley                 26               25.3
# 6             Chelsea                 28               25.0
# 7      Crystal Palace                 24               27.7
# 8             Everton                 25               27.4
# 9              Fulham                 24               29.3
# 10          Liverpool                 23               27.3
# 11         Luton Town                 23               27.2
# 12    Manchester City                 25               27.0
# 13     Manchester Utd                 29               27.0
# ...

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0
#                Squad               # Pl                Age               Poss
# 0            Arsenal                 23               25.3               60.3  \
# 1        Aston Villa                 26               27.4               55.2
# 2        Bournemouth                 25               26.1               44.2
# 3          Brentford                 26               27.1               48.3
# 4           Brighton                 27               26.7               61.1
#
#   Playing Time                    Performance      ... Per 90 Minutes
#             MP Starts   Min   90s         Gls Ast  ...            Gls   Ast
# 0           20    220  1800  20.0          36  23  ...           1.80  1.15  \
# 1           21    231  1890  21.0          40  30  ...           1.90  1.43
# 2           19    209  1768  19.6          28  20  ...           1.43  1.02
# ...

# %%
df.columns = [' '.join(col).strip() for col in df.columns]

df = df.reset_index(drop=True)
df.head()
# Out:
#   Unnamed: 0_level_0 Squad  Unnamed: 1_level_0 # Pl  Unnamed: 2_level_0 Age
# 0                  Arsenal                       23                    25.3  \
# 1              Aston Villa                       26                    27.4
# 2              Bournemouth                       25                    26.1
# 3                Brentford                       26                    27.1
# 4                 Brighton                       27                    26.7
#
#    Unnamed: 3_level_0 Poss  Playing Time MP  Playing Time Starts
# 0                     60.3               20                  220  \
# 1                     55.2               21                  231
# 2                     44.2               19                  209
# 3                     48.3               19                  209
# 4                     61.1               20                  220
#
#    Playing Time Min  Playing Time 90s  Performance Gls  Performance Ast  ...
# ...

# %%
new_columns = []
for col in df.columns:
  if 'level_0' in col:
      new_col = col.split()[-1]  # takes the last name
  else:
      new_col = col
  new_columns.append(new_col)

# rename columns
df.columns = new_columns
df = df.fillna(0)

df.head()
# Out:
#          Squad  Pl   Age  Poss  Playing Time MP  Playing Time Starts
# 0      Arsenal  23  25.3  60.3               20                  220  \
# 1  Aston Villa  26  27.4  55.2               21                  231
# 2  Bournemouth  25  26.1  44.2               19                  209
# 3    Brentford  26  27.1  48.3               19                  209
# 4     Brighton  27  26.7  61.1               20                  220
#
#    Playing Time Min  Playing Time 90s  Performance Gls  Performance Ast  ...
# 0              1800              20.0               36               23  ...  \
# 1              1890              21.0               40               30  ...
# 2              1768              19.6               28               20  ...
# 3              1710              19.0               25               16  ...
# 4              1800              20.0               36               28  ...
#
#    Per 90 Minutes Gls  Per 90 Minutes Ast  Per 90 Minutes G+A
# ...

# %%
df
# Out:
#               Squad  Pl   Age  Poss  Playing Time MP  Playing Time Starts
# 0           Arsenal  23  25.3  60.3               20                  220  \
# 1       Aston Villa  26  27.4  55.2               21                  231
# 2       Bournemouth  25  26.1  44.2               19                  209
# 3         Brentford  26  27.1  48.3               19                  209
# 4          Brighton  27  26.7  61.1               20                  220
# 5           Burnley  26  25.3  47.2               21                  231
# 6           Chelsea  28  25.0  59.0               21                  231
# 7    Crystal Palace  24  27.7  42.9               20                  220
# 8           Everton  25  27.4  39.1               21                  231
# 9            Fulham  24  29.3  49.9               21                  231
# 10        Liverpool  23  27.3  60.2               20                  220
# 11       Luton Town  23  27.2  38.6               20                  220
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Squad                    20 non-null     object
#  1   Pl                       20 non-null     int64
#  2   Age                      20 non-null     float64
#  3   Poss                     20 non-null     float64
#  4   Playing Time MP          20 non-null     int64
#  5   Playing Time Starts      20 non-null     int64
#  6   Playing Time Min         20 non-null     int64
#  7   Playing Time 90s         20 non-null     float64
#  8   Performance Gls          20 non-null     int64
#  9   Performance Ast          20 non-null     int64
#  10  Performance G+A          20 non-null     int64
#  11  Performance G-PK         20 non-null     int64
#  12  Performance PK           20 non-null     int64
#  13  Performance PKatt        20 non-null     int64
# ...

# %%
df.describe()
# Out:
#               Pl        Age       Poss  Playing Time MP  Playing Time Starts
# count  20.000000  20.000000  20.000000        20.000000            20.000000  \
# mean   25.700000  26.930000  49.950000        20.300000           223.300000
# std     2.273416   1.098372   8.810311         0.656947             7.226414
# min    23.000000  25.000000  36.200000        19.000000           209.000000
# 25%    23.750000  26.475000  42.325000        20.000000           220.000000
# 50%    25.500000  27.050000  49.100000        20.000000           220.000000
# 75%    27.250000  27.400000  59.075000        21.000000           231.000000
# max    30.000000  29.300000  64.100000        21.000000           231.000000
#
#        Playing Time Min  Playing Time 90s  Performance Gls  Performance Ast
# count         20.000000         20.000000        20.000000        20.000000  \
# mean        1832.800000         20.360000        30.200000        21.850000
# ...

# %%
df.columns
# Out:
# Index(['Squad', 'Pl', 'Age', 'Poss', 'Playing Time MP', 'Playing Time Starts',
#        'Playing Time Min', 'Playing Time 90s', 'Performance Gls',
#        'Performance Ast', 'Performance G+A', 'Performance G-PK',
#        'Performance PK', 'Performance PKatt', 'Performance CrdY',
#        'Performance CrdR', 'Expected xG', 'Expected npxG', 'Expected xAG',
#        'Expected npxG+xAG', 'Progression PrgC', 'Progression PrgP',
#        'Per 90 Minutes Gls', 'Per 90 Minutes Ast', 'Per 90 Minutes G+A',
#        'Per 90 Minutes G-PK', 'Per 90 Minutes G+A-PK', 'Per 90 Minutes xG',
#        'Per 90 Minutes xAG', 'Per 90 Minutes xG+xAG', 'Per 90 Minutes npxG',
#        'Per 90 Minutes npxG+xAG'],
#       dtype='object')

# %%
df
# Out:
#               Squad  Pl   Age  Poss  Playing Time MP  Playing Time Starts
# 0           Arsenal  23  25.3  60.3               20                  220  \
# 1       Aston Villa  26  27.4  55.2               21                  231
# 2       Bournemouth  25  26.1  44.2               19                  209
# 3         Brentford  26  27.1  48.3               19                  209
# 4          Brighton  27  26.7  61.1               20                  220
# 5           Burnley  26  25.3  47.2               21                  231
# 6           Chelsea  28  25.0  59.0               21                  231
# 7    Crystal Palace  24  27.7  42.9               20                  220
# 8           Everton  25  27.4  39.1               21                  231
# 9            Fulham  24  29.3  49.9               21                  231
# 10        Liverpool  23  27.3  60.2               20                  220
# 11       Luton Town  23  27.2  38.6               20                  220
# ...

# %%
df.rename(columns={"Pl": "Squad Size"})
# Out:
#               Squad  Squad Size   Age  Poss  Playing Time MP
# 0           Arsenal          23  25.3  60.3               20  \
# 1       Aston Villa          26  27.4  55.2               21
# 2       Bournemouth          25  26.1  44.2               19
# 3         Brentford          26  27.1  48.3               19
# 4          Brighton          27  26.7  61.1               20
# 5           Burnley          26  25.3  47.2               21
# 6           Chelsea          28  25.0  59.0               21
# 7    Crystal Palace          24  27.7  42.9               20
# 8           Everton          25  27.4  39.1               21
# 9            Fulham          24  29.3  49.9               21
# 10        Liverpool          23  27.3  60.2               20
# 11       Luton Town          23  27.2  38.6               20
# 12  Manchester City          25  27.0  64.1               20
# 13   Manchester Utd          29  27.0  52.0               21
# ...

# %%
df = df.rename(columns={"Poss": "Possession", "MP": "Matches"})

# %%
df.rename(columns={"Playing Time MP": "Matches"})
# Out:
#               Squad  Pl   Age  Poss  Matches  Playing Time Starts
# 0           Arsenal  23  25.3  60.3       20                  220  \
# 1       Aston Villa  26  27.4  55.2       21                  231
# 2       Bournemouth  25  26.1  44.2       19                  209
# 3         Brentford  26  27.1  48.3       19                  209
# 4          Brighton  27  26.7  61.1       20                  220
# 5           Burnley  26  25.3  47.2       21                  231
# 6           Chelsea  28  25.0  59.0       21                  231
# 7    Crystal Palace  24  27.7  42.9       20                  220
# 8           Everton  25  27.4  39.1       21                  231
# 9            Fulham  24  29.3  49.9       21                  231
# 10        Liverpool  23  27.3  60.2       20                  220
# 11       Luton Town  23  27.2  38.6       20                  220
# 12  Manchester City  25  27.0  64.1       20                  220
# ...

# %%
df
# Out:
#               Squad  Pl   Age  Possession  Playing Time MP
# 0           Arsenal  23  25.3        60.3               20  \
# 1       Aston Villa  26  27.4        55.2               21
# 2       Bournemouth  25  26.1        44.2               19
# 3         Brentford  26  27.1        48.3               19
# 4          Brighton  27  26.7        61.1               20
# 5           Burnley  26  25.3        47.2               21
# 6           Chelsea  28  25.0        59.0               21
# 7    Crystal Palace  24  27.7        42.9               20
# 8           Everton  25  27.4        39.1               21
# 9            Fulham  24  29.3        49.9               21
# 10        Liverpool  23  27.3        60.2               20
# 11       Luton Town  23  27.2        38.6               20
# 12  Manchester City  25  27.0        64.1               20
# 13   Manchester Utd  29  27.0        52.0               21
# 14    Newcastle Utd  30  27.9        53.3               21
# ...

# %%
df  = df.rename(columns={"Pl": "Squad Size"})

# %%
df
# Out:
#               Squad  Squad Size   Age  Possession  Playing Time MP
# 0           Arsenal          23  25.3        60.3               20  \
# 1       Aston Villa          26  27.4        55.2               21
# 2       Bournemouth          25  26.1        44.2               19
# 3         Brentford          26  27.1        48.3               19
# 4          Brighton          27  26.7        61.1               20
# 5           Burnley          26  25.3        47.2               21
# 6           Chelsea          28  25.0        59.0               21
# 7    Crystal Palace          24  27.7        42.9               20
# 8           Everton          25  27.4        39.1               21
# 9            Fulham          24  29.3        49.9               21
# 10        Liverpool          23  27.3        60.2               20
# 11       Luton Town          23  27.2        38.6               20
# 12  Manchester City          25  27.0        64.1               20
# ...

# %%
df = df.rename(columns={"Playing Time MP": "Matches"})

# %%
df = df.rename(columns={"Playing Time Starts": "Starts"})

# %%
df = df.rename(columns={"Playing Time Min": "Minutes"})

# %%
df = df.rename(columns={"Playing Time 90s": "90s"})

# %%
df
# Out:
#               Squad  Squad Size   Age  Possession  Matches  Starts  Minutes
# 0           Arsenal          23  25.3        60.3       20     220     1800  \
# 1       Aston Villa          26  27.4        55.2       21     231     1890
# 2       Bournemouth          25  26.1        44.2       19     209     1768
# 3         Brentford          26  27.1        48.3       19     209     1710
# 4          Brighton          27  26.7        61.1       20     220     1800
# 5           Burnley          26  25.3        47.2       21     231     1890
# 6           Chelsea          28  25.0        59.0       21     231     1890
# 7    Crystal Palace          24  27.7        42.9       20     220     1800
# 8           Everton          25  27.4        39.1       21     231     1890
# 9            Fulham          24  29.3        49.9       21     231     1890
# 10        Liverpool          23  27.3        60.2       20     220     1800
# ...

# %%
# Assuming 'data' is your DataFrame
plt.scatter(df['Performance Gls'], df['Performance Ast'])
plt.xlabel('Goals')
plt.ylabel('Assists')
plt.title('Goals vs Assists')
plt.show()

# %%
# Assuming 'data' is your DataFrame
plt.hist(df['Age'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Number of Players')
plt.title('Age Distribution of Squads')
plt.show()

# %%
# Assuming 'data' is your DataFrame
bar_width = 0.35  # Width of each bar
index = np.arange(len(df['Squad']))  # Generate an array of indices for each squad

plt.figure(figsize=(12, 6))

plt.bar(index, df['Progression PrgC'], label='Progression PrgC', width=bar_width, color='blue')
plt.bar(index + bar_width, df['Progression PrgP'], label='Progression PrgP', width=bar_width, color='orange', alpha=0.7)

plt.xlabel('Squad')
plt.ylabel('Progression Metrics')
plt.legend()
plt.title('Progression Metrics for Each Squad')
plt.xticks(index + bar_width / 2, df['Squad'], rotation=45, ha='right')  # Set x-axis ticks at the center of each group
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.barh(index, df['Progression PrgC'], label='Progression PrgC', color='blue')
plt.barh(index, df['Progression PrgP'], left=df['Progression PrgC'], label='Progression PrgP', color='orange', alpha=0.7)
plt.ylabel('Squad')
plt.xlabel('Progression Metrics')
plt.legend()
plt.title('Progression Metrics for Each Squad')
plt.yticks(index, df['Squad'])
plt.show()

# %%
plt.scatter(df['Performance Gls'], df['Expected xG'])
plt.xlabel('Actual Goals (Performance Gls)')
plt.ylabel('Expected Goals (Expected xG)')
plt.title('Comparison of Actual Goals vs Expected Goals')
plt.grid(True)
plt.show()

# %%
plt.scatter(df['Performance Gls'], df['Expected xG'])

# Adding labels for each point based on the index
for i, txt in enumerate(df.index):
    plt.annotate(txt, (df['Performance Gls'][i], df['Expected xG'][i]))

plt.xlabel('Actual Goals (Performance Gls)')
plt.ylabel('Expected Goals (Expected xG)')
plt.title('Comparison of Actual Goals vs Expected Goals')
plt.grid(True)
plt.show()

# %%
df.Squad
# Out:
# 0             Arsenal
# 1         Aston Villa
# 2         Bournemouth
# 3           Brentford
# 4            Brighton
# 5             Burnley
# 6             Chelsea
# 7      Crystal Palace
# 8             Everton
# 9              Fulham
# 10          Liverpool
# 11         Luton Town
# 12    Manchester City
# 13     Manchester Utd
# 14      Newcastle Utd
# 15    Nott'ham Forest
# 16      Sheffield Utd
# 17          Tottenham
# 18           West Ham
# 19             Wolves
# Name: Squad, dtype: object

# %%
team_names = {
    0: 'Arsenal',
    1: 'Aston Villa',
    2: 'Bournemouth',
    3: 'Brentford',
    4: 'Brighton',
    5: 'Burnley',
    6: 'Chelsea',
    7: 'Crystal Palace',
    8: 'Everton',
    9: 'Fulham',
    10: 'Liverpool',
    11: 'Luton Town',
    12: 'Manchester City',
    13: 'Manchester Utd',
    14: 'Newcastle Utd',
    15: 'Nott\'ham Forest',
    16: 'Sheffield Utd',
    17: 'Tottenham',
    18: 'West Ham',
    19: 'Wolves'
}

plt.scatter(df['Performance Gls'], df['Expected xG'])

# Adding labels for each point based on the index names
for i, team_name in team_names.items():
    plt.annotate(team_name, (df.loc[i, 'Performance Gls'], df.loc[i, 'Expected xG']))

plt.xlabel('Actual Goals')
plt.ylabel('Expected Goals')
plt.title('Comparison of Actual Goals vs Expected Goals')
plt.grid(True)
plt.show()

# %%
team_abbreviations = {
    0: 'ARS',
    1: 'AVL',
    2: 'BOU',
    3: 'BRE',
    4: 'BRI',
    5: 'BUR',
    6: 'CHE',
    7: 'CRY',
    8: 'EVE',
    9: 'FUL',
    10: 'LIV',
    11: 'LUT',
    12: 'MCI',
    13: 'MUN',
    14: 'NEW',
    15: 'NFO',
    16: 'SHU',
    17: 'TOT',
    18: 'WHU',
    19: 'WOL'
}

plt.scatter(df['Performance Gls'], df['Expected xG'])

# Adding labels for each point based on the index abbreviations
for i, team_abbr in team_abbreviations.items():
    plt.annotate(team_abbr, (df.loc[i, 'Performance Gls'], df.loc[i, 'Expected xG']))

plt.xlabel('Actual Goals')
plt.ylabel('Expected Goals')
plt.title('Comparison of Actual Goals vs Expected Goals')
plt.grid(True)
plt.show()

# %%
# Assuming 'df' is your DataFrame with the provided index names
team_abbreviations = {
    0: 'ARS', 1: 'AVL', 2: 'BOU', 3: 'BRE', 4: 'BRI', 5: 'BUR',
    6: 'CHE', 7: 'CRY', 8: 'EVE', 9: 'FUL', 10: 'LIV', 11: 'LUT',
    12: 'MCI', 13: 'MUN', 14: 'NEW', 15: 'NFO', 16: 'SHU', 17: 'TOT',
    18: 'WHU', 19: 'WOL'
}

plt.scatter(df['Performance Gls'], df['Expected xG'])

# Adding labels for each point based on the index abbreviations
for i, team_abbr in team_abbreviations.items():
    plt.annotate(team_abbr, (df.loc[i, 'Performance Gls'], df.loc[i, 'Expected xG']))

# Draw a diagonal line
plt.plot([df['Performance Gls'].min(), df['Performance Gls'].max()], 
         [df['Performance Gls'].min(), df['Performance Gls'].max()], 
         linestyle='--', color='gray', label='x=y')

# Label points based on their position relative to the diagonal line
for i, team_abbr in team_abbreviations.items():
    if df.loc[i, 'Performance Gls'] > df.loc[i, 'Expected xG']:
        label = 'Outperforming xG'
    else:
        label = 'Underperforming xG'
    plt.text(df.loc[i, 'Performance Gls'], df.loc[i, 'Expected xG'], label)

plt.xlabel('Actual Goals')
plt.ylabel('Expected Goals')
plt.title('Comparison of Actual Goals vs Expected Goals')
plt.legend()
plt.grid(True)
plt.show()

# %%
df
# Out:
#                                         Squad  Squad Size   Age  Possession
# typing.Literal[<no_default>]
# 0                                     Arsenal          23  25.3        60.3  \
# 1                                 Aston Villa          26  27.4        55.2
# 2                                 Bournemouth          25  26.1        44.2
# 3                                   Brentford          26  27.1        48.3
# 4                                    Brighton          27  26.7        61.1
# 5                                     Burnley          26  25.3        47.2
# 6                                     Chelsea          28  25.0        59.0
# 7                              Crystal Palace          24  27.7        42.9
# 8                                     Everton          25  27.4        39.1
# 9                                      Fulham          24  29.3        49.9
# 10                                  Liverpool          23  27.3        60.2
# ...

# %%
#FINALLLLLLLLLLLLLLLLLLLLLLLL

# Assuming 'df' is your DataFrame with the provided index names
team_abbreviations = {
    0: 'ARS', 1: 'AVL', 2: 'BOU', 3: 'BRE', 4: 'BRI', 5: 'BUR',
    6: 'CHE', 7: 'CRY', 8: 'EVE', 9: 'FUL', 10: 'LIV', 11: 'LUT',
    12: 'MCI', 13: 'MUN', 14: 'NEW', 15: 'NFO', 16: 'SHU', 17: 'TOT',
    18: 'WHU', 19: 'WOL'
}

plt.scatter(df['Performance Gls'], df['Expected xG'])

# Adding labels for each point based on the index abbreviations
for i, team_abbr in team_abbreviations.items():
    plt.annotate(team_abbr, (df.loc[i, 'Performance Gls'], df.loc[i, 'Expected xG']))

# Draw a diagonal line
plt.plot([df['Performance Gls'].min(), df['Performance Gls'].max()], 
         [df['Performance Gls'].min(), df['Performance Gls'].max()], 
         linestyle='--', color='gray')



plt.xlabel('Actual Goals (Performance Gls)')
plt.ylabel('Expected Goals (Expected xG)')
plt.title('Comparison of Actual Goals vs Expected Goals')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['Goals_Deviation'] = df['Performance Gls'] - df['Expected xG']

# Adjust saturation for slightly desaturated green and red
colors = ['lightgreen' if x >= 0 else 'lightcoral' for x in df['Goals_Deviation']]

plt.figure(figsize=(10, 6))
sns.barplot(x='Squad', y='Goals_Deviation', data=df, palette=colors)
plt.axhline(0, color='black', linewidth=1)  # Reference line at y=0
plt.title('Deviation of Actual Goals from Expected Goals')
plt.xlabel('Team')
plt.ylabel('Goals Deviation')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

from matplotlib.table import Table


league_positions = [3, 5, 7, 4, 10, 19, 13, 8, 12, 17, 9, 16, 2, 14, 1, 20, 6, 18, 11, 15]
table_data = []
for i, (index, row) in enumerate(df_sorted.iterrows()):
    table_data.append([row['Squad'], row['Goals_Deviation'], league_positions[i]])

table = plt.table(cellText=table_data, colLabels=['Team', 'Goals Deviation', 'League Position'], cellLoc='center', loc='bottom')
table.auto_set_font_size(False)
table.set_fontsize(10)

# Formatting the table
table.scale(1, 1.5)
plt.axis('off')  # Hide the axes
plt.show()
# Out:
# /var/folders/p4/r3j6q60j5pl02xbyk_p9m3hh0000gn/T/ipykernel_11949/2725854304.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
from matplotlib.table import Table


league_positions = [3, 5, 7, 4, 10, 19, 13, 8, 12, 17, 9, 16, 2, 14, 1, 20, 6, 18, 11, 15]
table_data = []
for i, (index, row) in enumerate(df_sorted.iterrows()):
    table_data.append([row['Squad'], row['Goals_Deviation'], league_positions[i]])

table = plt.table(cellText=table_data, colLabels=['Team', 'Goals Deviation', 'League Position'], cellLoc='center', loc='bottom')
table.auto_set_font_size(False)
table.set_fontsize(10)

# Formatting the table
table.scale(1, 1.5)
plt.axis('off')  # Hide the axes
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
df['Goals_Deviation'] = df['Performance Gls'] - df['Expected xG']

# New league positions
new_league_positions = [2, 4, 12, 15, 8, 19, 11, 14, 18, 13, 1, 17, 3, 6, 9, 16, 20, 5, 7, 10]

# Add 'League Position' to DataFrame
df['League Position'] = new_league_positions

# Sort DataFrame by 'League Position'
df_sorted = df.sort_values(by='League Position')

# Adjust saturation for slightly desaturated green and red
colors = ['lightgreen' if x >= 0 else 'lightcoral' for x in df_sorted['Goals_Deviation']]

# Plotting
plt.figure(figsize=(10, 6))

# Use 'League Position' for the x-axis in the bar plot
sns.barplot(x='Squad', y='Goals_Deviation', data=df_sorted, palette=colors)
plt.axhline(0, color='black', linewidth=1)  # Reference line at y=0
plt.title('Deviation of Actual Goals from Expected Goals')
plt.xlabel('Squads')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Goals Deviation')

plt.show()


df['Goals_Deviation'] = df['Performance Gls'] - df['Expected xG']

# New league positions
new_league_positions = [2, 4, 12, 15, 8, 19, 11, 14, 18, 13, 1, 17, 3, 6, 9, 16, 20, 5, 7, 10]

# Add 'League Position' to DataFrame
df['League Position'] = new_league_positions

# Sort DataFrame by 'League Position'
df_sorted = df.sort_values(by='League Position')

# Table
table_data = []
for i, (index, row) in enumerate(df_sorted.iterrows()):
    table_data.append([row['Squad'], row['Goals_Deviation'], row['League Position']])

fig, ax = plt.subplots(figsize=(10, 6))
table = ax.table(cellText=table_data, colLabels=['Team', 'Goals Deviation', 'League Position'], cellLoc='center', loc='bottom')
table.auto_set_font_size(False)
table.set_fontsize(10)

# Formatting the table
table.scale(1, 1.5)

# Adjusting margins to remove empty borders
plt.subplots_adjust(left=0.2, bottom=0.2, right=0.8, top=0.8)
plt.axis('off') 
plt.show()
# Out:
# /var/folders/p4/r3j6q60j5pl02xbyk_p9m3hh0000gn/T/ipykernel_11949/1321126567.py:24: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
plt.scatter(df['Possession'], df['Expected xG'])

# Adding labels for each point based on the index abbreviations
for i, team_abbr in team_abbreviations.items():
    plt.annotate(team_abbr, (df.loc[i, 'Possession'], df.loc[i, 'Expected xG']))




plt.xlabel('Possession')
plt.ylabel('Expected Goals (Expected xG)')
plt.title('Comparison of Possession vs Expected Goals')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
plt.scatter(df['Performance Ast'], df['Expected xAG'])

# Adding labels for each point based on the index abbreviations
for i, team_abbr in team_abbreviations.items():
    plt.annotate(team_abbr, (df.loc[i, 'Performance Ast'], df.loc[i, 'Expected xAG']))

plt.plot([df['Performance Gls'].min(), df['Performance Gls'].max()], 
         [df['Performance Gls'].min(), df['Performance Gls'].max()], 
         linestyle='--', color='gray')

plt.xlabel('Assists')
plt.ylabel('Expected Assists (xAG)')
plt.title('Scatter Plot of Assists vs Expected Assists')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
df['Assists_Deviation'] = df['Performance Ast'] - df['Expected xAG']

# Define a color palette for positive and negative deviations
colors = ['lightgreen' if x >= 0 else 'lightcoral' for x in df['Assists_Deviation']]

plt.figure(figsize=(10, 6))

# Use 'Assists_Deviation' as the y-axis for the bar plot
sns.barplot(x='Squad', y='Assists_Deviation', data=df, palette=colors)
plt.axhline(0, color='black', linewidth=1)  # Reference line at y=0
plt.title('Deviation of Actual Assists from Expected Assists')
plt.xlabel('Team')
plt.ylabel('Goals Deviation')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()
# Out:
# /var/folders/p4/r3j6q60j5pl02xbyk_p9m3hh0000gn/T/ipykernel_11949/2900957317.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Squad', y='Assists_Deviation', data=df, palette=colors)

# %%
df_sorted = df.sort_values(by='Assists_Deviation', ascending=False)

table_data = []
for i, (index, row) in enumerate(df_sorted.iterrows()):
    table_data.append([row['Squad'], row['Assists_Deviation']])

# Create a figure and axis without the bar plot
fig, ax = plt.subplots(figsize=(8, 6))

# Add a table to the axes
table = ax.table(cellText=table_data,
                 colLabels=['Team', 'Assists Deviation'],
                 cellLoc='center',
                 loc='center',
                 colColours=['#f2f2f2', '#f5f5f5'])  # Adjust the number of colors to match the number of columns

# Formatting the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Hide the axes
ax.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
plt.scatter(df['Progression PrgP'], df['Expected xAG'])

# Adding labels for each point based on the index abbreviations
for i, team_abbr in team_abbreviations.items():
    plt.annotate(team_abbr, (df.loc[i, 'Progression PrgP'], df.loc[i, 'Expected xAG']))

plt.xlabel('Progression (PrgP)')
plt.ylabel('Expected Assists (xA)')
plt.title('Scatter Plot of Progression vs Expected Assists')
plt.grid(True)
plt.show()

# %%
# Assuming 'df' is your original DataFrame
df['Penalty Kick goals per 90'] = df['Per 90 Minutes Gls'] - df['Per 90 Minutes G-PK']

# %%
df
# Out:
#               Squad  Squad Size   Age  Possession  Matches  Starts  Minutes
# 0           Arsenal          23  25.3        60.3       20     220     1800  \
# 1       Aston Villa          26  27.4        55.2       21     231     1890
# 2       Bournemouth          25  26.1        44.2       19     209     1768
# 3         Brentford          26  27.1        48.3       19     209     1710
# 4          Brighton          27  26.7        61.1       20     220     1800
# 5           Burnley          26  25.3        47.2       21     231     1890
# 6           Chelsea          28  25.0        59.0       21     231     1890
# 7    Crystal Palace          24  27.7        42.9       20     220     1800
# 8           Everton          25  27.4        39.1       21     231     1890
# 9            Fulham          24  29.3        49.9       21     231     1890
# 10        Liverpool          23  27.3        60.2       20     220     1800
# ...

# %%
# Assuming 'df' is your DataFrame with the new column
heatmap_data = df.pivot_table(index='Squad', values='Penalty Kick goals per 90', aggfunc='mean')

# Sort the DataFrame by the values in the 'Penalty Kick goals per 90' column in descending order
heatmap_data_sorted = heatmap_data.sort_values(by='Penalty Kick goals per 90', ascending=False)

plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data_sorted, annot=True, cmap='viridis', fmt='.2f', linewidths=.5)
plt.title('Heatmap of Penalty Kick Goals per 90 for 20 Teams (Sorted)')
plt.show()
